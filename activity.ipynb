# %%
import numpy as np
import pandas as pd

# %%
d1={'name':['shree','Ayusha','Arati',' Yashwini','Shreeniti',],
    'ID':[1,2,3,4,5],
    'Salary':[100,300,np.nan,pd.NaT,400],
    'Role':['CEO',None,pd.NaT,pd.NaT,pd.NaT]}

# %%
df=pd.DataFrame(d1)

# %%
print(df)
# Out:
#         name  ID Salary  Role
# 0      shree   1    100   CEO
# 1     Ayusha   2    300  None
# 2      Arati   3    NaN   NaT
# 3   Yashwini   4    NaT   NaT
# 4  Shreeniti   5    400   NaT

# %%
df.head(2)
# Out:
#      name  ID Salary  Role
# 0   shree   1    100   CEO
# 1  Ayusha   2    300  None

# %%
df.tail(3)
# Out:
#         name  ID Salary Role
# 2      Arati   3    NaN  NaT
# 3   Yashwini   4    NaT  NaT
# 4  Shreeniti   5    400  NaT

# %%
df.isnull().sum()
# Out:
# name      0
# ID        0
# Salary    2
# Role      4
# dtype: int64
